# %% [markdown]
# # team myzw
# ### ToDo
# 逆強化学習
# 相対概念
# セマンティックマッピング
# シグバース
# 能動的地図学習
#
# TODO
# * 特徴量抽出
#  * wordコードブック作成
# 　* vision
#  * motion
# * mMLDA学習
# * BHMM学習
# * HMM学習[学習＋プランニング]
# * 言語からZの推定

# %%
import pandas as pd
import numpy as np
import MeCab
from word_client import WordClient
word_client = WordClient()
import glob
import os

# %%
type(tmp.sentence.values[0])
# Out:
# str

# %%
pd.read_csv("../../../data/caption.csv",sep=",",delimiter=None)
# Out:
#     Unnamed: 0  index          time  \
# 0            0     14  1.533107e+09
# 1            1      0  1.533107e+09
# 2            2      1  1.533107e+09
# 3            3     15  1.533107e+09
# 4            4      2  1.533107e+09
# 5            5      3  1.533108e+09
# 6            6     16  1.533108e+09
# 7            7      4  1.533108e+09
# 8            8      5  1.533108e+09
# 9            9     17  1.533108e+09
# 10          10      6  1.533108e+09
# 11          11     23  1.533108e+09
# 12          12     18  1.533109e+09
# 13          13      7  1.533109e+09
# 14          14     24  1.533109e+09
# 15          15      8  1.533109e+09
# 16          16     25  1.533110e+09
# 17          17     19  1.533110e+09
# 18          18      9  1.533110e+09
# 19          19     26  1.533110e+09
# 20          20     20  1.533110e+09
# 21          21     10  1.533110e+09
# 22          22     27  1.533111e+09
# 23          23     21  1.533111e+09
# 24          24     11  1.533111e+09
# 25          25     28  1.533111e+09
# 26          26     12  1.533111e+09
# 27          27     29  1.533111e+09
# 28          28     22  1.533111e+09
# 29          29     13  1.533111e+09
#
#                                              sentence  category  \
# 0   ['\xe3\x82\xad\xe3\x83\x83\xe3\x83\x81\xe3\x83...         1
# 1   ['\xe3\x83\xaa\xe3\x83\x93\xe3\x83\xb3\xe3\x82...         0
# 2   ['\xe3\x83\xaa\xe3\x83\x93\xe3\x83\xb3\xe3\x82...         0
# 3   ['\xe3\x82\xad\xe3\x83\x83\xe3\x83\x81\xe3\x83...         1
# 4   ['\xe3\x83\xaa\xe3\x83\x93\xe3\x83\xb3\xe3\x82...         0
# 5   ['\xe3\x83\xaa\xe3\x83\x93\xe3\x83\xb3\xe3\x82...         0
# 6   ['\xe3\x82\xad\xe3\x83\x83\xe3\x83\x81\xe3\x83...         1
# 7   ['\xe3\x83\xaa\xe3\x83\x93\xe3\x83\xb3\xe3\x82...         0
# 8   ['\xe3\x83\xaa\xe3\x83\x93\xe3\x83\xb3\xe3\x82...         0
# 9   ['\xe3\x82\xad\xe3\x83\x83\xe3\x83\x81\xe3\x83...         1
# 10  ['\xe3\x83\xaa\xe3\x83\x93\xe3\x83\xb3\xe3\x82...         0
# 11  ['\xe3\x83\x89\xe3\x82\xa2\xe5\x89\x8d\xe3\x81...         2
# 12  ['\xe3\x82\xad\xe3\x83\x83\xe3\x83\x81\xe3\x83...         1
# 13  ['\xe3\x83\xaa\xe3\x83\x93\xe3\x83\xb3\xe3\x82...         0
# 14  ['\xe3\x83\x89\xe3\x82\xa2\xe5\x89\x8d\xe3\x81...         2
# 15  ['\xe3\x83\xaa\xe3\x83\x93\xe3\x83\xb3\xe3\x82...         0
# 16  ['\xe3\x83\x89\xe3\x82\xa2\xe5\x89\x8d\xe3\x81...         2
# 17  ['\xe3\x82\xad\xe3\x83\x83\xe3\x83\x81\xe3\x83...         1
# 18  ['\xe3\x83\xaa\xe3\x83\x93\xe3\x83\xb3\xe3\x82...         0
# 19  ['\xe3\x83\x89\xe3\x82\xa2\xe5\x89\x8d\xe3\x81...         2
# 20  ['\xe3\x82\xad\xe3\x83\x83\xe3\x83\x81\xe3\x83...         1
# 21  ['\xe3\x83\xaa\xe3\x83\x93\xe3\x83\xb3\xe3\x82...         0
# 22  ['\xe3\x83\x89\xe3\x82\xa2\xe5\x89\x8d\xe3\x81...         2
# 23  ['\xe3\x82\xad\xe3\x83\x83\xe3\x83\x81\xe3\x83...         1
# 24  ['\xe3\x83\xaa\xe3\x83\x93\xe3\x83\xb3\xe3\x82...         0
# 25  ['\xe3\x83\x89\xe3\x82\xa2\xe5\x89\x8d\xe3\x81...         2
# 26  ['\xe3\x83\xaa\xe3\x83\x93\xe3\x83\xb3\xe3\x82...         0
# 27  ['\xe3\x83\x89\xe3\x82\xa2\xe5\x89\x8d\xe3\x81...         2
# 28  ['\xe3\x82\xad\xe3\x83\x83\xe3\x83\x81\xe3\x83...         1
# 29  ['\xe3\x83\xaa\xe3\x83\x93\xe3\x83\xb3\xe3\x82...         0
#
#                                            action  task
# 0                        [3, 3, 2, 2, 2, 2, 0, 0]     0
# 1                                 [3, 3, 3, 0, 1]     0
# 2                              [2, 3, 3, 3, 3, 1]     1
# 3                  [3, 3, 3, 3, 3, 3, 3, 1, 0, 0]     2
# 4                                       [3, 0, 1]     2
# 5                              [2, 3, 3, 0, 0, 1]     3
# 6                  [3, 3, 3, 3, 1, 1, 0, 0, 0, 0]     3
# 7                                       [3, 3, 0]     4
# 8                                       [2, 3, 1]     5
# 9                        [3, 3, 3, 3, 1, 0, 0, 0]     6
# 10                                   [2, 3, 0, 1]     6
# 11                 [0, 6, 6, 6, 6, 6, 1, 5, 4, 0]     7
# 12                             [3, 3, 2, 2, 0, 0]     7
# 13                                [3, 3, 3, 0, 1]     7
# 14  [0, 0, 6, 6, 6, 6, 1, 1, 1, 5, 5, 4, 4, 0, 0]     8
# 15                                   [2, 3, 3, 1]     8
# 16              [0, 6, 6, 6, 1, 5, 4, 0, 3, 3, 3]    12
# 17                             [3, 3, 3, 1, 0, 0]    12
# 18                             [2, 3, 3, 0, 0, 1]    12
# 19                    [0, 0, 6, 6, 6, 1, 5, 4, 0]    13
# 20                                   [3, 3, 1, 0]    13
# 21                                   [3, 3, 0, 1]    13
# 22              [0, 6, 6, 1, 1, 1, 5, 5, 4, 3, 3]    14
# 23                       [3, 3, 3, 3, 3, 3, 1, 0]    14
# 24                                      [3, 0, 1]    14
# 25                       [0, 6, 6, 1, 5, 4, 3, 3]    15
# 26                                   [2, 3, 0, 1]    15
# 27                    [0, 6, 6, 6, 1, 1, 5, 4, 3]    17
# 28                       [3, 3, 3, 3, 1, 0, 0, 0]    17
# 29                                   [3, 3, 0, 1]    17

# %%
pd.read_csv?

# %%
pd.read_csv("../../../data/caption.csv").sentence[0]

# %% [markdown]
# ### 岩田さん　データ形成

# %%
iwata_data_path = "../../../data/caption/"

# %%
try:
    os.mkdir(os.path.join(iwata_data_path,"RecogData"))
    os.mkdir(os.path.join(iwata_data_path,"RecogData/words"))
except:
    pass

# %%
ls ../../../data/caption/
# Out:
# RecogData/        exp_crest_08_13/  exp_crest_08_2/  exp_crest_08_6/
# exp_crest_08_0/   exp_crest_08_14/  exp_crest_08_3/  exp_crest_08_7/
# exp_crest_08_1/   exp_crest_08_15/  exp_crest_08_4/  exp_crest_08_8/
# exp_crest_08_12/  exp_crest_08_17/  exp_crest_08_5/

# %%
place_list = ["キッチン","リビング","ドア前"]
objects_list = ["box","pettobotle","door"]
GP_CLASS_NUM = 4
GP_TYPE_NUM = 3
class_nums = [GP_CLASS_NUM for i in range(GP_TYPE_NUM)]
START_CLASS = GP_CLASS_NUM
END_CLASS = GP_CLASS_NUM + 1

# %%
task_list = []
action_list = []
caption_list = []
objects_list = []
place_list = []
correct_object = []
correct_motion = []
scene_id = 0
vision_eye = np.eye(len(class_nums))

for task_id in range(1,7):
    action_num = len(glob.glob(os.path.join(iwata_data_path,"exp_crest_{0}".format(task_id),"action*")))
    for action_id in range(action_num):
        caption_path = os.path.join(iwata_data_path,"exp_crest_{0}/caption{1:03d}.txt".format(task_id,action_id))
        motions_path = os.path.join(iwata_data_path,"exp_crest_{0}/action{1:03d}.txt".format(task_id,action_id))
        place_path = os.path.join(iwata_data_path,"exp_crest_{0}/index{1:03d}.txt".format(task_id,action_id))
        motions = np.loadtxt(motions_path, delimiter=",", skiprows=1,dtype=np.int32)
        object_id = np.loadtxt(motions_path, delimiter=",", usecols=0,dtype=np.int32)[0]
        place = pd.read_csv(place_path,header=None)
        
        caption = pd.read_csv(caption_path,header=None)
        caption.columns = ["sentences"]
        caption["secne_id"] = scene_id
        caption_list.append(caption)
        objects_list.append(vision_eye[object_id])
        
        place_hist = np.zeros(100)
        for i,idx in enumerate(place.iloc[:,0].value_counts().index):
            place_hist[idx] = place.iloc[:,0].value_counts().values[i]
        place_list.append(place_hist)
        
        correct_object.append(object_id)
        correct_motion.append(object_id)
        
        motions = np.insert(motions,0,[START_CLASS,END_CLASS])
        motions = motions +  object_id*7
        tmp_motion_hists = []
        for i in range(7*len(class_nums)):
            tmp_motion_hists.append(len(np.where(motions==i)[0]))
        action_list.append(tmp_motion_hists)
        
        scene_id+= 1

# %%
np.savetxt(os.path.join(iwata_data_path,"RecogData/motion.Motion"),np.array(action_list),fmt="%d")
np.savetxt(os.path.join(iwata_data_path,"RecogData/vision.Object"),np.array(objects_list),fmt="%d")
np.savetxt(os.path.join(iwata_data_path,"RecogData/place.Place"),np.array(place_list),fmt="%d")

np.savetxt(os.path.join(iwata_data_path,"RecogData/CorrectObject.txt"),np.array(correct_object),fmt="%d")
np.savetxt(os.path.join(iwata_data_path,"RecogData/CorrectMotion.txt"),np.array(correct_motion),fmt="%d")

# %%
caption_pd = pd.concat(caption_list,axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-3ea12de63e90> in <module>()
# ----> 1 caption_pd = pd.concat(caption_list,axis=0)
#
# /home/miyazawa/anaconda2/lib/python2.7/site-packages/pandas/core/reshape/concat.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     204                        keys=keys, levels=levels, names=names,
#     205                        verify_integrity=verify_integrity,
# --> 206                        copy=copy)
#     207     return op.get_result()
#     208
#
# /home/miyazawa/anaconda2/lib/python2.7/site-packages/pandas/core/reshape/concat.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     237
#     238         if len(objs) == 0:
# --> 239             raise ValueError('No objects to concatenate')
#     240
#     241         if keys is None:
#
# ValueError: No objects to concatenate

# %%
caption_pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3832d55abbae> in <module>()
# ----> 1 caption_pd
#
# NameError: name 'caption_pd' is not defined

# %%
caption_pd.sentences.to_csv(os.path.join(iwata_data_path,"RecogData/sentences.txt"),index=False)

# %%
for i in range(1,17):
    word_dir = os.path.join(iwata_data_path,"RecogData/words/{0:03d}".format(i))
    try:
        os.mkdir(word_dir)
    except:
        pass
    
    word_client.update(word_dir)
    word_client.setAccept()
    # word の処理
    for sen in caption_pd[caption_pd.secne_id==i].sentences.values:
        word_client.sentence_data_cb(sen)
    word_client.setReject()
    word_client.split_sentences(word_dir)
    word_client.sumalize_utter(word_dir)
    sentences_file_path = os.path.join(word_dir,"sentences.txt")
    word_client.update_word_codebook(sentences_file_path)
    word_client.words2histogram(
    os.path.join(word_dir,"sentences.txt"),
    os.path.join(word_dir,"hist.txt")
    )
    word_client.dump_codebook(os.path.join(word_dir,"codebook.txt"))
# Out:
# ドア 前 で ドア を 開ける
#
# ドア 前 で ドア を 押す
#
# ココア ドア 前 だ よ
#
# ドア 前 で ドア を 開く
#
# ドア から 入る
#
# ドア 前 で ドア を 開い た
#
# ドア から 入る
#
# ドア 前 で ドア を 開ける
#
# ドア 前 で ドア を 開い た
#
# ドア 前 で ドア を 開く
#
# ココア ドア 前 だ よ
#
# ドア 前 で ドア を 押す
#
# キッチン
#
# キッチン で 物 を 設置 する
#
# キッチン で 物 を 置く
#
# キッチン で 物 を 置く
#
# キッチン で 物 を 置い た
#
# キッチン
#
# これ が キッチン だ よ
#
# キッチン で 物 を 置い た
#
# キッチン
#
# キッチン
#
# キッチン で 物 を 置く
#
# これ が キッチン だ よ
#
# キッチン で 物 を 置く
#
# キッチン で 物 を 設置 する
#
# ココア ドア 前 だ よ
#
# 寝室 から 出る
#
# 風呂 で 飲み物 を 置く
#
# ココア 風呂 だ よ
#
# 寝室 で 飲み物 を つかむ
#
# 風呂 で 飲み物 を 置い た
#
# 寝室 で 飲み物 を 味 する
#
# 風呂 に 着い た
#
# 風呂 です
#
# これ が 真実 です
#
# 風呂 で 飲み物 を 設置 し た
#
# 親子 で 飲み物 を 掴ん だ
#
# 風呂 で 物 を 置く
#
# 寝室 で 飲み物 に 手 を 伸ばし た
#
# 寝室 で 飲み物 を はじ し た
#
# ドア 前 です
#
# 風呂 で 飲み物 を 設置 する
#
# ドア 前 です
#
# 風呂 で 飲み物 を 設置 し た
#
# 風呂 で 物 を 置く
#
# 風呂 です
#
# 親子 で 飲み物 を 掴ん だ
#
# 風呂 に 着い た
#
# 寝室 で 飲み物 を つかむ
#
# ココア ドア 前 だ よ
#
# 風呂 で 飲み物 を 置い た
#
# ココア 風呂 だ よ
#
# 寝室 で 飲み物 を はじ し た
#
# 寝室 で 飲み物 に 手 を 伸ばし た
#
# 寝室 で 飲み物 を 味 する
#
# 風呂 で 飲み物 を 置く
#
# 寝室 から 出る
#
# これ が 真実 です
#
# 風呂 で 飲み物 を 設置 する
#
# 風呂 で 飲み物 を 置い た
#
# 風呂 で 飲み物 を 設置 し た
#
# 風呂 で 飲み物 を 設置 する
#
# 風呂 で 飲み物 を 置い た
#
# 風呂 で 飲み物 を 設置 する
#
# 風呂 で 飲み物 を 設置 し た
#
# 親子 で ぬいぐるみ を 把持 する
#
# 寝室 で ぬいぐるみ を 掴ん だ
#
# 寝室 で ぬいぐるみ を つかむ
#
# 寝室 で ぬいぐるみ を 握っ た
#
# 寝室 から ぬいぐるみ を 運ぶ
#
# 寝室 から ぬいぐるみ を 運ぶ
#
# 親子 で ぬいぐるみ を 把持 する
#
# 寝室 で ぬいぐるみ を 握っ た
#
# 寝室 で ぬいぐるみ を つかむ
#
# 寝室 で ぬいぐるみ を 掴ん だ
#
# ドア 前 で ドア を 開ける
#
# ドア 前 で ドア を 押す
#
# ここ は ドア 前 です
#
# ドア 前 で ドア を 押し上げる
#
# ドア 前 で ドア を 開ける
#
# ドア 前 で ドア を 押し上げる
#
# ここ は ドア 前 です
#
# ドア 前 で ドア を 押す
#
# キッチン の 机 に 設置 する
#
# キッチン の 机 に 置く
#
# キッチン の 机 に 置く
#
# キッチン の 机 に 置い た
#
# キッチン の 机 に 設置 する
#
# キッチン の 机 に 置い た
#
# キッチン の 机 に 置く
#
# キッチン の 机 に 置く
#
# プロ の 店 に 置く
#
# プロレス
#
# プロ の 店 に 設置 し た
#
# 親子 で ぬいぐるみ を つかむ
#
# うさぎ の ぬいぐるみ を 寝 室 で つかむ
#
# 風呂 の 棚 に 置い た
#
# 風呂 の 棚 に 置い た
#
# 親子 で ぬいぐるみ おにぎり
#
# 禁酒 で ぬいぐるみ を 掴ん だ
#
# ココア 風呂 です
#
# 寝室 から で
#
# 風呂 の 棚 に 置く
#
# 寝室 から で
#
# 禁酒 で ぬいぐるみ を 掴ん だ
#
# 風呂 の 棚 に 置く
#
# 親子 で ぬいぐるみ おにぎり
#
# うさぎ の ぬいぐるみ を 寝 室 で つかむ
#
# プロ の 店 に 置く
#
# 風呂 の 棚 に 置い た
#
# 親子 で ぬいぐるみ を つかむ
#
# 風呂 の 棚 に 置い た
#
# プロ の 店 に 設置 し た
#
# プロレス
#
# ココア 風呂 です
#
# 風呂 の 棚 に 置い た
#
# プロ の 店 に 設置 し た
#
# 風呂 の 棚 に 置く
#
# 風呂 の 棚 に 置い た
#
# 風呂 の 棚 に 置い た
#
# 風呂 の 棚 に 置い た
#
# 風呂 の 棚 に 置く
#
# プロ の 店 に 設置 し た
#
# スイス から 果物 を 運ぶ
#
# 寝室 に 果物 を 採る
#
# フェイス で 果物 に 手 を 伸ばす
#
# 親子 で 果物 を 掴ん だ
#
# スイス から 果物 を 運ぶ
#
# 親子 で 果物 を 掴ん だ
#
# フェイス で 果物 に 手 を 伸ばす
#
# 寝室 に 果物 を 採る
#
# ドア 前 で ドア を 押す
#
# ドア 前 で ドア を 開く
#
# ドア 前 で ドア を 開ける
#
# フォア 前 で ドア を 開ける
#
# ドア 前 で ドア を 押す
#
# フォア 前 で ドア を 開ける
#
# ドア 前 で ドア を 開ける
#
# ドア 前 で ドア を 開く
#
# キッチン の 上 に 置く
#
# キッチン の 机 に 設置 する
#
# キッチン に 置く
#
# キッチン の 机 に 置く
#
# キッチン の 机 に 設置 する
#
# キッチン の 机 に 設置 する
#
# キッチン の 上 に 置く
#
# キッチン の 机 に 置く
#
# キッチン に 置く
#
# キッチン の 机 に 設置 する
#
# キッチン の 机 に 設置 する
#
# キッチン の 机 に 設置 する
#
# 寝室 で 果物 を 掴ん だ
#
# 寝室 で フルーツ を つかむ
#
# 寝室 で 果物 を 握る
#
# 寝室 で 果物 を つかむ
#
# 親子 で 果物 を 把持 する
#
# 親子 で 果物 を 握る
#
# 親子 で 果物 を 採る
#
# 親子 で 果物 を 把持 する
#
# 寝室 で 果物 を 掴ん だ
#
# 親子 で 果物 を 握る
#
# 寝室 で 果物 を つかむ
#
# 親子 で 果物 を 採る
#
# 寝室 で 果物 を 握る
#
# 寝室 で フルーツ を つかむ
#
# 風呂 の 棚 に 置く
#
# プロ の 店 に 設置 する
#
# 風呂
#
# 風呂 の 棚 に 置い た
#
# 風呂 の 棚 に 置い た
#
# 黒 の 皿 に 設置 し た
#
# 風呂 の 棚 に 置い た
#
# 風呂 の 棚 に 置く
#
# 黒 の 皿 に 設置 し た
#
# 風呂 の 棚 に 置い た
#
# 風呂
#
# プロ の 店 に 設置 する

# %%
words_hists = []
for i in range(1,17):
    word_hist_path = os.path.join(iwata_data_path,"RecogData/words/{0:03d}/hist.txt".format(i))
    words_hists.append(np.loadtxt(word_hist_path))

# %%
np.savetxt(os.path.join(iwata_data_path,"RecogData/words.All"),np.array(words_hists),fmt="%d")

# %%
action_num_list = []
for task_id in range(1,17):
    action_num = len(glob.glob(os.path.join(iwata_data_path,"exp_environment_{0}".format(task_id),"action*")))
    action_num_list.append(action_num)

# %%
np.savetxt("/home/robocup/Desktop/miyazawa_crest_2018/caption/action_nums.txt",action_num_list,fmt="%d")

# %%
all_sentence = []
for i in range(1,17):
    word_hist_path = os.path.join(iwata_data_path,"RecogData/words/{0:03d}/sentences.txt".format(i))
    tmp_sen_list = np.loadtxt(word_hist_path,dtype=str,delimiter="\n").tolist()
    if type(tmp_sen_list) is str:
        tmp_sen_list = [tmp_sen_list]
    all_sentence.extend(tmp_sen_list)
sentences_path = os.path.join(iwata_data_path,"RecogData/sentences.txt")
np.savetxt(sentences_path,all_sentence,fmt="%s")
# Out:
# /home/robocup/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: loadtxt: Empty input file: "/home/robocup/Desktop/miyazawa_crest_2018/caption/RecogData/words/016/sentences.txt"

# %%
print all_sentence[0]
# Out:
# ドア から 入る

# %% [markdown]
# 進捗
# ドアを作っているところ
# 物体の情報を
#
# jointトラジェクトリー
#
# 場所概念の可視化
#
# 場所概念
# 既知概念環境で
#
# GP-HSMM:rosbagで学習できる
# IK:シグバース
# 学習データ：
#
#
# 場所概念の学習時間：

# %% [markdown]
# ### 場所概念の正解を与える

# %%
import IPython

# %%
place_correct = []
exp_dirs = glob.glob(os.path.join(iwata_data_path,"exp_environment*"))
exp_dirs.sort()
for exp in exp_dirs:
    captions = glob.glob(os.path.join(exp,"caption*"))
    captions.sort()
    for caption in captions:
        tmp = np.loadtxt(caption,dtype=str)
        try:
            for i in tmp:
                print i
        except:
            print tmp
        print ""
        print caption
        print ""
        print "寝室：    0"
        print "キッチン: 1"
        print "風呂:     2"
        print "ドア:     3"
        print "書斎:     4"
        
        place_correct.append(int(raw_input("place_id")))
        
        IPython.display.clear_output()

# %%
place_eye = np.eye(4)
place_hist = []
for place in place_correct:
    place_hist.append(place_eye[place])
np.savetxt(os.path.join(iwata_data_path,"RecogData/CorrectPlace.txt"),place_correct,fmt="%d")

np.savetxt(os.path.join(iwata_data_path,"RecogData/place.Place"),place_hist,fmt="%d")
